# %% [markdown]
# Importierung der benötigten Module

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
con = sqlite3.connect('RecipeDB.db')

ing_df = pd.read_sql('SELECT ingID FROM Ingredients', con)
al_df = pd.read_sql('SELECT alleID FROM Allergens', con)
tag_df = pd.read_sql('Select tagID FROM Tags', con)
recs_df = pd.read_sql('SELECT recID From Recipe', con)

print( ing_df.shape, "....", al_df.shape, '......', tag_df.shape,'.....', recs_df.shape)
# Out:
# (832, 1) .... (14, 1) ...... (25, 1) ..... (1897, 1)

# %%
tags = [x for x in tag_df['tagID']]
ings = [x for x in ing_df['ingID']]
alls = [x for x in al_df['alleID']]

columns = tags+ings+alls
print(len(columns))
index = [x for x in recs_df['recID']]
print(len(index))
# Out:
# 871
# 1897

# %%
data  =np.zeros((len(index), len(columns)), dtype=np.bool_)
data.shape
df= pd.DataFrame(data=data,index = index,columns = columns)

# %%
df
# Out:
#                           57d13370b7e8697d4b30530e  57d13370b7e8697d4b30530f  \
# 53f45a29ff604dac328b456e                     False                     False
# 5469feafff604d2c8b8b4569                     False                     False
# 54c91e3e6ced6e5f178b4571                     False                     False
# 54c91e716ced6e39178b456c                     False                     False
# 54c91ed56ced6e5f178b4572                     False                     False
# ...                                            ...                       ...
# 5c30b8a7c445fa33f45d3002                     False                     False
# 5c30bb90c445fa36747c59b2                     False                     False
# 5c30c098e3f33962d2048221                     False                     False
# 5c30c1bbc445fa3bc376fc02                     False                     False
# 5c30c44ec445fa3dbb5a80b2                     False                     False
#
# ...

# %%
big_ass_table = pd.read_sql('SELECT recID, ingID, tagID, alleID FROM Recipe NATURAL JOIN IngInRec Natural Join Ingredients NATURAL JOIN AlleInRec NATURAL JOIN TagsInRec;', con)
big_ass_table.head()
# Out:
#                       recID                     ingID  \
# 0  54c91e3e6ced6e5f178b4571  554b19befd2cb959598b4576
# 1  54c91e3e6ced6e5f178b4571  554b19befd2cb959598b4576
# 2  54c91e3e6ced6e5f178b4571  554b19befd2cb959598b4576
# 3  5549e9016ced6e08738b4567  554b19befd2cb959598b4576
# 4  5549e9016ced6e08738b4567  554b19befd2cb959598b4576
#
#                       tagID                    alleID
# 0  57d13370b7e8697d4b30531a  57962a07b7e8697d4b3052f3
# 1  57d13370b7e8697d4b30531a  57962a07b7e8697d4b3052f5
# 2  57d13370b7e8697d4b30531a  57962a07b7e8697d4b3052fa
# 3  57d13370b7e8697d4b305316  57962a07b7e8697d4b3052fd
# 4  57d13370b7e8697d4b30531a  57962a07b7e8697d4b3052fd

# %%
testrec = '54c91e3e6ced6e5f178b4571'
testid = '57d13370b7e8697d4b30530e'
testtt = '57962a07b7e8697d4b3052f3'
mask = (big_ass_table['recID'] == testrec) & ((big_ass_table['ingID'] == testid) | (big_ass_table['tagID'] == testid) |(big_ass_table['alleID'] == testid))
mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150584    False
# 150585    False
# 150586    False
# 150587    False
# 150588    False
# Length: 150589, dtype: bool

# %%
# for row in big_ass_table.itertuples():
#     df.loc[row.recID][row.ingID] = True
#     df.loc[row.recID][row.tagID] = True
#     df.loc[row.recID][row.alleID] = True

cur = con.cursor()
for ing in cur.execute("SELECT ingID, recID FROM IngInRec ;").fetchall():
    df.loc[ing[1]][ing[0]] = True
    
for ing in cur.execute("SELECT tagID, recID FROM TagsInRec ;").fetchall():
    df.loc[ing[1]][ing[0]] = True
    
for ing in cur.execute("SELECT alleID, recID FROM AlleInRec ;").fetchall():
    df.loc[ing[1]][ing[0]] = True

df.head()
# Out:
#                           57d13370b7e8697d4b30530e  57d13370b7e8697d4b30530f  \
# 53f45a29ff604dac328b456e                     False                     False
# 5469feafff604d2c8b8b4569                      True                     False
# 54c91e3e6ced6e5f178b4571                     False                     False
# 54c91e716ced6e39178b456c                     False                     False
# 54c91ed56ced6e5f178b4572                     False                     False
#
#                           57d13370b7e8697d4b305311  57d13370b7e8697d4b305313  \
# 53f45a29ff604dac328b456e                     False                     False
# 5469feafff604d2c8b8b4569                     False                     False
# 54c91e3e6ced6e5f178b4571                     False                     False
# 54c91e716ced6e39178b456c                     False                     False
# 54c91ed56ced6e5f178b4572                     False                     False
#
# ...

# %%
df.describe()
# Out:
#        57d13370b7e8697d4b30530e 57d13370b7e8697d4b30530f  \
# count                      1897                     1897
# unique                        2                        2
# top                       False                    False
# freq                       1362                     1896
#
#        57d13370b7e8697d4b305311 57d13370b7e8697d4b305313  \
# count                      1897                     1897
# unique                        2                        2
# top                       False                    False
# freq                       1856                     1893
#
#        57d13370b7e8697d4b305314 57d13370b7e8697d4b305315  \
# count                      1897                     1897
# unique                        2                        2
# top                       False                    False
# freq                       1865                     1751
#
#        57d13370b7e8697d4b305316 57d13370b7e8697d4b305317  \
# ...

# %%
recipe_csv = df.to_csv('recipeBool.csv', index = True)
