# %% [markdown]
# # The Questions

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from sklearn.feature_extraction.text import CountVectorizer
 
from sklearn.feature_extraction.text import TfidfVectorizer
 
from sklearn.metrics.pairwise import cosine_similarity

path = os.path.realpath('../Data')

bool_df = pd.read_csv(path+"/recipeBool.csv")
bool_df.index = bool_df["Unnamed: 0"]
bool_df = bool_df.drop(["Unnamed: 0"], axis = 1)
columns = bool_df.columns

# %%
bool_df.head()
# Out:
#                           57d13370b7e8697d4b30530e  57d13370b7e8697d4b30530f  \
# Unnamed: 0
# 53f45a29ff604dac328b456e                     False                     False
# 5469feafff604d2c8b8b4569                      True                     False
# 54c91e3e6ced6e5f178b4571                     False                     False
# 54c91e716ced6e39178b456c                     False                     False
# 54c91ed56ced6e5f178b4572                     False                     False
#
#                           57d13370b7e8697d4b305311  57d13370b7e8697d4b305313  \
# Unnamed: 0
# 53f45a29ff604dac328b456e                     False                     False
# 5469feafff604d2c8b8b4569                     False                     False
# 54c91e3e6ced6e5f178b4571                     False                     False
# 54c91e716ced6e39178b456c                     False                     False
# 54c91ed56ced6e5f178b4572                     False                     False
#
#                           57d13370b7e8697d4b305314  57d13370b7e8697d4b305315  \
# Unnamed: 0
# 53f45a29ff604dac328b456e                     False                     False
# 5469feafff604d2c8b8b4569                     False                     False
# 54c91e3e6ced6e5f178b4571                     False                     False
# 54c91e716ced6e39178b456c                     False                     False
# 54c91ed56ced6e5f178b4572                     False                     False
#
#                           57d13370b7e8697d4b305316  57d13370b7e8697d4b305317  \
# Unnamed: 0
# 53f45a29ff604dac328b456e                     False                     False
# 5469feafff604d2c8b8b4569                     False                      True
# 54c91e3e6ced6e5f178b4571                     False                     False
# 54c91e716ced6e39178b456c                      True                     False
# 54c91ed56ced6e5f178b4572                     False                      True
#
#                           57d13370b7e8697d4b305318  57d13370b7e8697d4b305319  \
# Unnamed: 0
# 53f45a29ff604dac328b456e                     False                     False
# 5469feafff604d2c8b8b4569                     False                     False
# 54c91e3e6ced6e5f178b4571                     False                     False
# 54c91e716ced6e39178b456c                     False                      True
# 54c91ed56ced6e5f178b4572                     False                     False
#
#                           ...  57962a07b7e8697d4b3052f7  \
# Unnamed: 0                ...
# 53f45a29ff604dac328b456e  ...                     False
# 5469feafff604d2c8b8b4569  ...                     False
# 54c91e3e6ced6e5f178b4571  ...                     False
# 54c91e716ced6e39178b456c  ...                     False
# 54c91ed56ced6e5f178b4572  ...                     False
#
#                           57962a07b7e8697d4b3052f8  57962a07b7e8697d4b3052f9  \
# Unnamed: 0
# 53f45a29ff604dac328b456e                     False                     False
# 5469feafff604d2c8b8b4569                     False                     False
# 54c91e3e6ced6e5f178b4571                     False                     False
# 54c91e716ced6e39178b456c                      True                     False
# 54c91ed56ced6e5f178b4572                     False                     False
#
#                           57962a07b7e8697d4b3052fa  57962a07b7e8697d4b3052fb  \
# Unnamed: 0
# 53f45a29ff604dac328b456e                      True                     False
# 5469feafff604d2c8b8b4569                      True                     False
# 54c91e3e6ced6e5f178b4571                      True                     False
# 54c91e716ced6e39178b456c                     False                     False
# 54c91ed56ced6e5f178b4572                      True                      True
#
#                           57962a07b7e8697d4b3052fc  57962a07b7e8697d4b3052fd  \
# Unnamed: 0
# 53f45a29ff604dac328b456e                     False                     False
# 5469feafff604d2c8b8b4569                     False                     False
# 54c91e3e6ced6e5f178b4571                     False                     False
# 54c91e716ced6e39178b456c                     False                     False
# 54c91ed56ced6e5f178b4572                     False                     False
#
#                           57962a07b7e8697d4b3052fe  57962a07b7e8697d4b3052ff  \
# Unnamed: 0
# 53f45a29ff604dac328b456e                     False                     False
# 5469feafff604d2c8b8b4569                     False                     False
# 54c91e3e6ced6e5f178b4571                     False                     False
# 54c91e716ced6e39178b456c                      True                     False
# 54c91ed56ced6e5f178b4572                     False                      True
#
#                           5a95b0bbae08b555554f4b52
# Unnamed: 0
# 53f45a29ff604dac328b456e                     False
# 5469feafff604d2c8b8b4569                     False
# 54c91e3e6ced6e5f178b4571                     False
# 54c91e716ced6e39178b456c                     False
# 54c91ed56ced6e5f178b4572                     False
#
# [5 rows x 871 columns]

# %% [markdown]
# ## Bei Einrichtung
# 1. Frage: Willst du einen Thermomix verwenden?
# 2. Frage: Nenne Zutaten, welche du nicht verwenden möchtest.
# 3. Frage: Hast du irgendwelche Alergien?
# 4. Frage: Besondere Ernährungsweise?
# 5. Frage: Wie bewertest du folgende 5 Gerichte? (0-5)

# %% [markdown]
# Funktion zu Erstellung eines Userprofiles:

# %%
#func to normalize text
def process_text(text):
    #replace muliple spaces with one
    test = ''.join(text.split())
    #lowercase
    text = text.lower()
    return text

# %%
#creating helping df´s for finden id´s

con = sqlite3.connect(path+"/RecipeDB.db")
# ing_df = pd.read_sql("Select * FROM IngFamily", con)
# temp = pd.read_sql('SELECT * FROM Ingredients',con)
# ing_df.index = ing_df["familyID"]
# for x in temp.itertuples():
#     ing_df.loc[x.familyID]['familyName']+= ' '+x.ingName
# ing_df = ing_df.drop(["familyID"], axis = 1)

# ing_df.rename(columns = {'familyName':'info'}, inplace = True)

ing_df = pd.read_sql("Select ingID, ingName, familyName FROM Ingredients NATURAL JOIN IngFamily", con)
ing_df.index = ing_df['ingID']
ing_df['info'] = ing_df['ingName'] +" "+ ing_df['familyName'];
ing_df = ing_df.drop(['ingName'], axis = 1)
ing_df = ing_df.drop(['familyName'], axis = 1)
ing_df = ing_df.drop(['ingID'], axis = 1)


ing_df['info'] = ing_df.apply(lambda x: process_text(x.info), axis = 1)


tags_df = pd.read_sql("Select * from Tags", con)
tags_df.index = tags_df["tagID"]
tags_df['info'] = tags_df['tagName']+' '+tags_df['tagType']
tags_df = tags_df.drop(["tagID"], axis = 1)
tags_df = tags_df.drop(["tagName"], axis = 1)
tags_df = tags_df.drop(["tagType"], axis = 1)

tags_df['info'] = tags_df.apply(lambda x: process_text(x.info), axis = 1)

alg_df = pd.read_sql("Select * from Allergens", con)
alg_df.index = alg_df["alleID"]
alg_df['info']= alg_df['alleType']+' '+alg_df['alleName']+' '+alg_df['alleSlug']
alg_df = alg_df.drop(["alleID"], axis = 1)
alg_df = alg_df.drop(["alleType"], axis = 1)
alg_df = alg_df.drop(["alleName"], axis = 1)
alg_df = alg_df.drop(["alleSlug"], axis = 1)

alg_df['info'] = alg_df.apply(lambda x: process_text(x.info), axis = 1)

thermo = tags_df[tags_df["info"].str.contains("thermomix")]

# %%
alg_df.head()
# Out:
#                                                                        info
# alleID
# 57962a07b7e8697d4b3052f5                               gluten weizen weizen
# 57962a07b7e8697d4b3052f3  maycontaintracesofallergens kann spuren von al...
# 57962a07b7e8697d4b3052fa                                 milk milch laktose
# 57962a07b7e8697d4b3052fd                                  mustard senf senf
# 57962a07b7e8697d4b3052f6                                          egg ei ei

# %%
ing_df
# Out:
#                                                     info
# ingID
# 554b7698fd2cb96c628b4568               arborio-reis reis
# 55a7a8f8fd2cb9570f8b4567      arabisches fladenbrot brot
# 556c4ed44dab710b3d8b4569                apfelessig essig
# 55535c2efd2cb9ae048b4567             aubergine aubergine
# 556db2a04dab71104b8b4568                  naan-brot brot
# ...                                                  ...
# 5bf2c4e9ae08b5103d1caae2  schinkenbraten schweinefleisch
# 5c1227bee3f33930ed6f7d42            apfelsaft fruchtsaft
# 5c0e62fac445fa5e3d20aa72               hühnerbrühe stock
# 5c1904c0c445fa108b691d62                    dorade fisch
# 57cda483544b18f5018b4568  ungesalzene erdnusskerne nüsse
#
# [832 rows x 1 columns]

# %%
tags_df.head()
# Out:
#                                                   info
# tagID
# 57d13370b7e8697d4b30531a   leichter genuss low-calorie
# 57d13370b7e8697d4b305319                  scharf spicy
# 58aeb96c99052d5fee3dd712    chef's choice chefs-choice
# 57d13370b7e8697d4b305317        vegetarisch vegetarian
# 57d13370b7e8697d4b30530e  zeit sparen under-30-minutes

# %%
test = (False, ["Schwein", "Tomaten", "Schimmelkäse"], ["Laktose", "Schwefel"], ["Protein", "fettarm"])
def create_Userprofile(tmix, ing, alg, tags):
    data = np.full([1, len(columns)], 0.25, dtype=np.float64)
    user_Profile = pd.DataFrame(data=data, columns = columns)
    for x in thermo.itertuples():
        user_Profile[x.Index] = 1.0 if tmix else 0.0
    for x in ing:
        for i in ing_df[ing_df['info'].str.contains(x.lower())].itertuples():
            #TODO sachen wie gewürzmischungen oder komplimentär zutaten werden auch gefunden 
            print('ing :',x,' id info', i.Index, ' ', i.info)
            user_Profile[i.Index] = 0;
            
    for a in alg:
        for i in alg_df[alg_df['info'].str.contains(a.lower())].itertuples():
            print('allergie :',a,' id info', i.Index, ' ', i.info)
            user_Profile[i.Index] = -1.0
            
    for tag in tags:
        for i in tags_df[tags_df['info'].str.contains(tag.lower())].itertuples():
            print('tag :',tag,' id info', i.Index, ' ', i.info)
            user_Profile[i.Index] = 5.0
    return user_Profile.iloc[0]

user_p = create_Userprofile(test[0], test[1], test[2], test[3])
# Out:
# ing : Schwein  id info 554b6b664dab71160d8b4569   schweinefilet schweinefleisch
# ing : Schwein  id info 555dabaff8b25e246a8b4568   speckwürfel schweinefleisch
# ing : Schwein  id info 556842e3f8b25efe3e8b456a   schinkenspeck schweinefleisch
# ing : Schwein  id info 55535376f8b25e8a038b4568   bacon schweinefleisch
# ing : Schwein  id info 556881724dab71111f8b4568   schweineschnitzel schweinefleisch
# ing : Schwein  id info 556c1b03f8b25eac648b4567   chorizo schweinefleisch
# ing : Schwein  id info 556c771bfd2cb9604e8b4568   schweinenacken schweinefleisch
# ing : Schwein  id info 5566efd9fd2cb952018b456a   schweinefleisch schweinefleisch
# ing : Schwein  id info 555341defd2cb92b1a8b456a   schweinerückensteak schweinefleisch
# ing : Schwein  id info 55704ae24dab71b7688b4569   schweinelachssteaks schweinefleisch
# ing : Schwein  id info 557050784dab71b7688b456a   pancetta schweinefleisch
# ing : Schwein  id info 5582c296f8b25e02648b4567   pulled pork schweinefleisch
# ing : Schwein  id info 55e84be279a23c827e8b4568   schweinbauch schweinefleisch
# ing : Schwein  id info 561e29734dab712f018b4567   vegankebab-döner schweinefleisch
# ing : Schwein  id info 5638bbd04dab71f1038b4567   prosciutto schweinefleisch
# ing : Schwein  id info 5638bf6a79a23c10638b4567   schweinelachs schweinefleisch
# ing : Schwein  id info 5638d677fd2cb980678b4567   gewürfelter bacon schweinefleisch
# ing : Schwein  id info 56fea28ef8b25ef0488b4569   truthahn-bacon schweinefleisch
# ing : Schwein  id info 57359a21f8b25e01478b4567   rohschinken schweinefleisch
# ing : Schwein  id info 574d50d1fd2cb9de318b4567   serranoschinken schweinefleisch
# ing : Schwein  id info 57e121f03933dcbd128b456a   gewürzmischung "schweinefilet" gewürzmischung
# ing : Schwein  id info 5b7d4d6aae08b518ed329882   schweinebraten schweinefleisch
# ing : Schwein  id info 5beacd68ae08b55d2d42be62   krustenbraten schweinefleisch
# ing : Schwein  id info 5bf2c4e9ae08b5103d1caae2   schinkenbraten schweinefleisch
# ing : Tomaten  id info 554b2621fd2cb99c598b4576   tomate tomaten
# ing : Tomaten  id info 554b2a87f8b25ef53e8b4573   kirschtomaten tomaten
# ing : Tomaten  id info 554b27104dab71a9058b456c   getrocknete tomaten tomaten
# ing : Tomaten  id info 556c08624dab7169208b4568   tomatenmark tomatenmark
# ing : Tomaten  id info 56e82251fd2cb95c628b4567   bunte kirschtomaten tomaten
# ing : Tomaten  id info 5568324ffd2cb9d8268b456a   stückige tomaten tomaten
# ing : Tomaten  id info 554b2226fd2cb9ba598b456c   tomatenpolpa tomaten
# ing : Tomaten  id info 55534dc3fd2cb990798b456a   passierte tomaten tomaten
# ing : Tomaten  id info 556d8a7c4dab713d4a8b4567   fleischtomate tomaten
# ing : Tomaten  id info 556da575fd2cb9d1088b456a   große tomate tomaten
# ing : Tomaten  id info 556eb9574dab7117538b4567   pomodori pelati tomaten
# ing : Tomaten  id info 556ec7d8fd2cb94f148b4567   gelbe kirschtomaten tomaten
# ing : Tomaten  id info 555d9e96f8b25e166a8b4567   kumato tomaten
# ing : Tomaten  id info 55cb7f874dab71f80d8b4567   grüne tomaten tomaten
# ing : Tomaten  id info 56433f1ef8b25edc4d8b4567   pizza-tomaten tomatenmark
# ing : Tomaten  id info 565ec0384dab71e10a8b4568   tomatenpassata tomatenmark
# ing : Tomaten  id info 56962e844dab71d11f8b4567   ochsenherztomaten kirschen
# ing : Tomaten  id info 56a8b5f9fd2cb90b798b4567   strauchtomaten tomaten
# ing : Tomaten  id info 56f11d42f8b25e1f408b4567   kirschtomaten tomaten
# ing : Tomaten  id info 575579ddf8b25e4d078b4567   datteltomaten tomaten
# ing : Tomaten  id info 575e8411f8b25ef0348b4569   roma-tomaten tomaten
# ing : Tomaten  id info 56782fac4dab7121768b4567   eiertomaten tomaten
# ing : Tomaten  id info 56cf023ffd2cb9a3218b4569   eiertomaten tomaten
# allergie : Laktose  id info 57962a07b7e8697d4b3052fa   milk milch laktose
# allergie : Schwefel  id info 57962a07b7e8697d4b3052ff   sulphites schwefel schwefel
# tag : Protein  id info 57d13370b7e8697d4b305321   proteinreich high-protein
# tag : fettarm  id info 57d13370b7e8697d4b305323   fettarm low-fat

# %% [markdown]
# ## Bei Normaler Verwendung
# ### 1. Option:
# Empfehlung eines Rezeptes
#
# ### 2. Option:
# Spezifischere Empfehlung durch folgende Frage:
# 1. Nenne Zutaten, welche du gerne verwenden möchtest.

# %%
bool_df.shape
# Out:
# (1808, 871)

# %%
user_p.shape
# Out:
# (871,)

# %% [markdown]
# ## TODO Knowledge Base Recommender

# %%
def know_recommender(user_profile):
    res = bool_df.dot(user_profile)
    for i in res.nlargest(1808).iteritems():
        yield i

# %%
#print(user_p)
count  = 0;
for i in know_recommender(user_p):
    count += 1
    print(i)
    if count == 5:
        break
# Out:
# ('58f9e3cb043c3c42b53b8792', 14.5)
# ('5902ec12171c584090693d02', 13.75)
# ('58ac4befd0d6bd680533bac4', 13.25)
# ('5858e0e67d69bf305c3a7752', 12.0)
# ('5902ee9331310006be1c8b72', 10.5)

# %% [markdown]
# ## TODO Contentend based Recommender

# %%
recipe_df = pd.read_sql("SELECT recID FROM Recipe;", con)
cur = con.cursor()

for id in recipe_df.itertuples():
    recipe_df.at[id.Index, 'ingredients'] = ''.join([i[0].lower()+" " for i in cur.execute("Select ingName from Ingredients NATURAL JOIN IngInRec WHERE recID = ?", (id.recID,)) ])

for id in recipe_df.itertuples():
    recipe_df.at[id.Index, 'tags'] = ''.join([i[0].lower()+" " for i in cur.execute("Select tagName from Tags NATURAL JOIN TagsInRec WHERE recID = ?", (id.recID,)) ])

for id in recipe_df.itertuples():
    recipe_df.at[id.Index, 'allergies'] = ''.join([i[0].lower()+" " for i in cur.execute("Select alleName from Allergens NATURAL JOIN AlleInRec WHERE recID = ?", (id.recID,)) ])

# %%
recipe_df
# Out:
#                          recID  \
# 0     53f45a29ff604dac328b456e
# 1     5469feafff604d2c8b8b4569
# 2     54c91e3e6ced6e5f178b4571
# 3     54c91e716ced6e39178b456c
# 4     54c91ed56ced6e5f178b4572
# ...                        ...
# 1803  5c309f47e3f339483f554ee2
# 1804  5c309f4ae3f339485b6c7272
# 1805  5c30b8a7c445fa33f45d3002
# 1806  5c30c098e3f33962d2048221
# 1807  5c30c1bbc445fa3bc376fc02
#
#                                             ingredients  \
# 0     salz* butter* olivenöl* zucker* gelbe paprika ...
# 1     öl* salz* zucker* mozzarella basilikum frische...
# 2     rinderhüftsteak rosmarin öl* salz* pfefferkörn...
# 3     roter chili öl* salz* pfefferkörner zucker* ka...
# 4     salz* pfefferkörner olivenöl* essig* karotte r...
# ...                                                 ...
# 1803  rinderhüftsteak salz* crème fraîche geriebener...
# 1804  rinderhüftsteak salz* crème fraîche geriebener...
# 1805  öl* salz* jasminreis frühlingszwiebel zuckersc...
# 1806  rinderhüftsteak rosmarin salz* zitrone kartoff...
# 1807  öl* salz* crème fraîche butter* frühlingszwieb...
#
#                                                    tags  \
# 0
# 1                              vegetarisch zeit sparen
# 2                                      leichter genuss
# 3                                      scharf low carb
# 4                                          vegetarisch
# ...                                                 ...
# 1803           leichter genuss vegetarisch zeit sparen
# 1804  leichter genuss vegetarisch zeit sparen thermo...
# 1805                       leichter genuss vegetarisch
# 1806
# 1807                                         thermomix
#
#                                               allergies
# 0     weizen milch kann spuren von allergenen enthal...
# 1     ei weizen milch kann spuren von allergenen ent...
# 2     milch weizen kann spuren von allergenen enthal...
# 3                                sesam erdnüsse weizen
# 4     weizen schalenfrüchte schwefel milch kann spur...
# ...                                                 ...
# 1803  milch weizen schwefel ei kann spuren von aller...
# 1804  milch weizen schwefel ei kann spuren von aller...
# 1805              kann spuren von allergenen enthalten
# 1806  milch weizen kann spuren von allergenen enthal...
# 1807                                   milch weizen ei
#
# [1808 rows x 4 columns]

# %%
def concatenate_features(ing, tags, allergies):
    w_ing = 3
    w_tag = 1
    w_allergies = 3;
    return process_text((ing*w_ing+tags*w_tag+allergies*w_allergies))

recipe_df['info'] = recipe_df.apply(lambda x : concatenate_features(x.ingredients, x.tags, x.allergies), axis = 1)

# %%
recipe_df.iloc[1]['info']
# Out:
# 'öl* salz* zucker* mozzarella basilikum frische gnocchi schalotte stückige tomaten italienische kräutermischung pfeffer* knoblauchzehe hartkäse ital. art bunte kirschtomaten frischer majoran öl* salz* zucker* mozzarella basilikum frische gnocchi schalotte stückige tomaten italienische kräutermischung pfeffer* knoblauchzehe hartkäse ital. art bunte kirschtomaten frischer majoran öl* salz* zucker* mozzarella basilikum frische gnocchi schalotte stückige tomaten italienische kräutermischung pfeffer* knoblauchzehe hartkäse ital. art bunte kirschtomaten frischer majoran vegetarisch zeit sparen ei weizen milch kann spuren von allergenen enthalten ei weizen milch kann spuren von allergenen enthalten ei weizen milch kann spuren von allergenen enthalten '

# %%
#saving the recipe csv
output_file = os.path.join(path,'recipe_feature_set.csv')
recipe_csv = recipe_df.to_csv(output_file, index = True)

# %%
vect = CountVectorizer()
 
vect_matrix = vect.fit_transform(recipe_df['info'])
 
cosine_similarity_matrix_count_based = cosine_similarity(vect_matrix, vect_matrix)

# %%
print(cosine_similarity_matrix_count_based)
# Out:
# [[1.         0.36927447 0.39073029 ... 0.37367949 0.40605178 0.41174614]
#  [0.36927447 1.         0.3607168  ... 0.34976707 0.3460259  0.25341223]
#  [0.39073029 0.3607168  1.         ... 0.36614634 0.47461415 0.34758389]
#  ...
#  [0.37367949 0.34976707 0.36614634 ... 1.         0.29179466 0.21369596]
#  [0.40605178 0.3460259  0.47461415 ... 0.29179466 1.         0.25007089]
#  [0.41174614 0.25341223 0.34758389 ... 0.21369596 0.25007089 1.        ]]

# %%
def index_to_recipeID(index, df):
    return df.loc[index]['recID']

print(index_to_recipeID(0,recipe_df))
# Out:
# 53f45a29ff604dac328b456e

# %%
def CoBaRe(recipe_id, cosine_similarity_matrix, df):
    index = df[df['recID']== recipe_id].index.values[0]
    similarity_scores = list(enumerate(cosine_similarity_matrix[index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    #delete the first cuz it´s itself lol
    print(similarity_scores.pop(0))
    for i in similarity_scores:
        yield index_to_recipeID(i[0],df);

# %%
test_df = pd.read_csv(path+'/recipe_feature_set.csv')
test_df.head()
# Out:
#    Unnamed: 0                     recID  \
# 0           0  53f45a29ff604dac328b456e
# 1           1  5469feafff604d2c8b8b4569
# 2           2  54c91e3e6ced6e5f178b4571
# 3           3  54c91e716ced6e39178b456c
# 4           4  54c91ed56ced6e5f178b4572
#
#                                          ingredients  \
# 0  salz* butter* olivenöl* zucker* gelbe paprika ...
# 1  öl* salz* zucker* mozzarella basilikum frische...
# 2  rinderhüftsteak rosmarin öl* salz* pfefferkörn...
# 3  roter chili öl* salz* pfefferkörner zucker* ka...
# 4  salz* pfefferkörner olivenöl* essig* karotte r...
#
#                        tags  \
# 0                       NaN
# 1  vegetarisch zeit sparen
# 2          leichter genuss
# 3          scharf low carb
# 4              vegetarisch
#
#                                            allergies  \
# 0  weizen milch kann spuren von allergenen enthal...
# 1  ei weizen milch kann spuren von allergenen ent...
# 2  milch weizen kann spuren von allergenen enthal...
# 3                             sesam erdnüsse weizen
# 4  weizen schalenfrüchte schwefel milch kann spur...
#
#                                                 info
# 0  salz* butter* olivenöl* zucker* gelbe paprika ...
# 1  öl* salz* zucker* mozzarella basilikum frische...
# 2  rinderhüftsteak rosmarin öl* salz* pfefferkörn...
# 3  roter chili öl* salz* pfefferkörner zucker* ka...
# 4  salz* pfefferkörner olivenöl* essig* karotte r...

# %% [markdown]
# ## TODO Hybrid

# %% [markdown]
# ## TODO Recipe to JSON parser

# %%
import json 
con = sqlite3.connect(path+"/RecipeDB.db")
cur = con.cursor();

def recipe_json(recipe_id):
    res = {}
    res['id'] = recipe_id
    sql = """ SELECT * FROM Recipe WHERE recID = ? ;"""
    recs = cur.execute(sql,(recipe_id,)).fetchall()[0]
    #basic infos
    res['name'] = recs[1]
    res['headline'] = recs[2]
    res['disc'] = recs[3]
    #ingredients
    recs = cur.execute("SELECT ingID, ingName, familyID, familyName, amount, unit FROM IngInRec NATURAL JOIN Ingredients NATURAL JOIN IngFamily WHERE recID = ? ;",(recipe_id,)).fetchall()
    ingr = {}
    for ing in recs:
        ingr[ing[0]] = {'name':ing[1],'amount': ing[4], 'unit': ing[5], 'family' : {'id':ing[2], 'name': ing[3]}}
    res['ingredients'] = ingr
    
    #nutr
    recs = cur.execute("SELECT nType, amount, unit, nName FROM NutrInRec NATURAL JOIN Nutration WHERE recID = ? ;",(recipe_id,)).fetchall()
    nutr = {}
    for i in recs:
        nutr[i[0]] = {'amount' : i[1], 'unit' : i[2], 'name' : i[3]}
    res['nutration'] = nutr
    
    #allergene
    recs = cur.execute("SELECT alleID, alleName FROM AlleInRec NATURAL JOIN Allergens WHERE recID = ? ;",(recipe_id,)).fetchall()
    alle = {}
    for i in recs:
        alle[i[0]] = i[1]
    res['allergies'] = alle
    
    #tags
    
    recs = cur.execute("SELECT tagID, tagName FROM TagsInRec NATURAL JOIN Tags WHERE recID = ? ;",(recipe_id,)).fetchall()
    tags = {}
    for t in recs:
        tags[t[0]] = t[1]
    res['tags'] = tags
    
    #steps
    recs = cur.execute("SELECT stepIndex, stepDisc from StepsInRec WHERE recID = ?  ORDER BY stepIndex ;", (recipe_id,)).fetchall();
    
    res['steps'] = [i[1]for i in recs]
    
    return json.dumps(res, indent=2, ensure_ascii=False)
    

for i in know_recommender(user_p):
    print(recipe_json(i[0]))
    for j in CoBaRe(i[0],cosine_similarity_matrix_count_based, recipe_df):
        print("CBS___________________________________________________________________________________________________________________________")
        print(recipe_json(j))
        break
    break
# Out:
# {
#   "id": "58f9e3cb043c3c42b53b8792",
#   "name": "Bulgogi! Koreanisches Rindfleisch",
#   "headline": "mit gedämpftem Gemüse und fluffigem Jasminreis",
#   "disc": "Zeit für einen kulinarischen Ausflug! Bulgogi ist ein traditionelles Rindfleischgericht und bedeutet wörtlich übersetzt Feuerfleisch. Der Name weist jedoch nicht auf die Schärfe hin, sondern auf die traditionelle Zubereitung über offenem Feuer. Wir kombinieren das saftige Rindfleisch mit einer großen Portion knackigem Gemüse und einer feurigen Gewürzmischung. Lass Dir dieses fettarme und proteinreiche Gericht schmecken!",
#   "ingredients": {
#     "57849ac477d68dc4708b4567": {
#       "name": "Rindergeschnetzeltes",
#       "amount": 140.0,
#       "unit": "g",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fb4e",
#         "name": "Rindfleisch"
#       }
#     },
#     "554b1f6efd2cb99c598b4575": {
#       "name": "Jasminreis",
#       "amount": 75.0,
#       "unit": "g",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc1c",
#         "name": "Reis"
#       }
#     },
#     "554b7b9efd2cb9d0608b456f": {
#       "name": "Brokkoli",
#       "amount": 0.5,
#       "unit": "Stück",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fb56",
#         "name": "Brokkoli"
#       }
#     },
#     "554b2abcf8b25eef3e8b4573": {
#       "name": "rote Zwiebel",
#       "amount": 0.5,
#       "unit": "Stück",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fbee",
#         "name": "Zwiebel"
#       }
#     },
#     "554b27e6fd2cb983608b4569": {
#       "name": "Frühlingszwiebel",
#       "amount": 0.5,
#       "unit": "Stück",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc35",
#         "name": "Frühlingszwiebel"
#       }
#     },
#     "554b23dff8b25ef53e8b456f": {
#       "name": "Karotte",
#       "amount": 0.5,
#       "unit": "Stück",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fb62",
#         "name": "Karotte"
#       }
#     },
#     "57ad86a877d68de53f8b4567": {
#       "name": "Gewürzmischung \"Bulgogi\"",
#       "amount": 1.0,
#       "unit": "g",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc32",
#         "name": "Gewürzmischung"
#       }
#     },
#     "554b7d36fd2cb9d8608b4570": {
#       "name": "Sojasoße",
#       "amount": 10.0,
#       "unit": "ml",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc30",
#         "name": "Sojasauce"
#       }
#     },
#     "58f71a23043c3c7a70455c82": {
#       "name": "Backpulver",
#       "amount": 2.0,
#       "unit": "g",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fb40",
#         "name": "Backpulver"
#       }
#     },
#     "5582cd024dab71bf498b4567": {
#       "name": "Kartoffelstärke",
#       "amount": 4.0,
#       "unit": "g",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fba0",
#         "name": "Mehl"
#       }
#     },
#     "554b1bf6f8b25eef3e8b4570": {
#       "name": "Öl*",
#       "amount": 0.0,
#       "unit": "Einheit",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fbe8",
#         "name": "Öl"
#       }
#     },
#     "554b1c284dab71a9058b456b": {
#       "name": "Salz*",
#       "amount": 0.0,
#       "unit": "Einheit",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc25",
#         "name": "Salz"
#       }
#     },
#     "55b0a135fd2cb9121e8b4567": {
#       "name": "Pfeffer*",
#       "amount": 0.0,
#       "unit": "Einheit",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc05",
#         "name": "Pfeffer (Gewürz)"
#       }
#     }
#   },
#   "nutration": {
#     "57b42a48b7e8697d4b30530d": {
#       "amount": 2377,
#       "unit": "kJ",
#       "name": "Energie (kJ)"
#     },
#     "57b42a48b7e8697d4b305304": {
#       "amount": 568,
#       "unit": "kcal",
#       "name": "Energie (kcal)"
#     },
#     "57b42a48b7e8697d4b305307": {
#       "amount": 12,
#       "unit": "g",
#       "name": "Fett"
#     },
#     "57b42a48b7e8697d4b305308": {
#       "amount": 4,
#       "unit": "g",
#       "name": "davon gesättigte Fettsäuren"
#     },
#     "57b42a48b7e8697d4b305305": {
#       "amount": 74,
#       "unit": "g",
#       "name": "Kohlenhydrate"
#     },
#     "57b42a48b7e8697d4b305306": {
#       "amount": 11,
#       "unit": "g",
#       "name": "davon Zucker"
#     },
#     "57b42a48b7e8697d4b30530a": {
#       "amount": 7,
#       "unit": "g",
#       "name": "Ballaststoffe"
#     },
#     "57b42a48b7e8697d4b305309": {
#       "amount": 42,
#       "unit": "g",
#       "name": "Eiweiß"
#     },
#     "57b42a48b7e8697d4b30530c": {
#       "amount": 0,
#       "unit": "mg",
#       "name": "Cholesterol"
#     },
#     "57b42a48b7e8697d4b30530b": {
#       "amount": 4,
#       "unit": "g",
#       "name": "Salz"
#     }
#   },
#   "allergies": {
#     "57962a07b7e8697d4b3052f5": "Weizen",
#     "57962a07b7e8697d4b3052f9": "Soja",
#     "57962a07b7e8697d4b3052f3": "kann Spuren von Allergenen enthalten"
#   },
#   "tags": {
#     "57d13370b7e8697d4b305321": "proteinreich",
#     "58aeb949c9fd0851d339ede2": "Neuentdeckung",
#     "57d13370b7e8697d4b305323": "fettarm",
#     "57d13370b7e8697d4b30531a": "leichter Genuss"
#   },
#   "steps": [
#     "Wasche Gemüse, Kräuter und Fleisch ab und tupfe das Fleisch mit Küchenpapier trocken. Erhitze 350 ml [700 ml] Wasser im Wasserkocher. Zum Kochen benötigst Du außerdem 1 große Schüssel, ein Sieb, 1 großen Topf (mit Deckel), 1 große Pfanne und Küchenpapier. Entdecke das koreanische Rindfleisch mit gedämpftem Gemüse.\nIn einer großen Schüssel Gewürzmischung mit Backpulver und Stärke sowie 1 EL [2 EL] kaltem Wasser glattrühren. Rindergeschnetzeltes darin marinieren.",
#     "Karotte schälen und in dünne Scheiben schneiden. Brokkoli in kleine Röschen aufteilen. Frühlingszwiebel in dünne Ringe schneiden. Rote Zwiebel schälen, halbieren und Hälften nochmals halbieren.",
#     "Jasminreis in einem Sieb mit kaltem Wasser abspülen, bis dieses klar hindurchfließt. 300 ml [600 ml] kochendes Wasser in einen großen Topf geben, salzen, aufkochen lassen, Reis zugeben und mit aufgesetztem Deckel bei niedriger Hitze ca. 10 Min. weiterköcheln lassen.",
#     "Ca. 5 Min. vor Ende der Reis-Garzeit Brokkoliröschen und Karottenscheiben in ein Sieb geben, über den Topf hängen und zugedeckt dämpfen lassen. Nach dem Ende der Reis-Garzeit Sieb mit dem Gemüse beiseitestellen. Topf vom Herd nehmen und Reis mind. 10 Min. abgedeckt ziehen lassen.",
#     "In einer großen Pfanne ½ EL [1 EL] Öl erhitzen und marinierte Rinderstreifen bei starker Hitze ca. 3 Min. anbraten. Anschließend salzen und pfeffern und aus der Pfanne nehmen. Erneut ½ EL [1 EL] Öl in der Pfanne erhitzen, weiße Frühlingszwiebelringe, Zwiebelviertel, Brokkoliröschen und Karottenscheiben zugeben und 3 – 5 Min. anbraten. Rindergeschnetzeltes zugeben. Sojasoße mit 50 ml [100 ml] heißem Wasser verdünnen und Inhalt der Pfanne damit ablöschen.",
#     "Reis mit einer Gabel auflockern, auf tiefe Teller verteilen, Bulgogi mit Karotten-Brokkoli-Gemüse darauf anrichten, mit den restlichen Frühlingszwiebelringen bestreuen und genießen."
#   ]
# }
# (1024, 1.0000000000000004)
# CBS___________________________________________________________________________________________________________________________
# {
#   "id": "5a5886aec9fd0877334d4ae2",
#   "name": "Hello Bulgogi! Koreanisches Rindfleisch",
#   "headline": "mit gedämpftem Gemüse und fluffigem Jasminreis",
#   "disc": "Für diesen kulinarischen Ausflug lohnt sich die etwas längere Zubereitungszeit allemal! Bulgogi ist ein fettarmes, koreanisches Rindfleischgericht und bedeutet wörtlich übersetzt Feuerfleisch. Keine Sorge, hierbei geht es nicht um den Geschmack, sondern um die traditionelle Zubereitung über offenem Feuer. Wir kombinieren das proteinreiche Rindfleisch mit einer großen Portion knackigem Gemüse und einer leicht feurigen Gewürzmischung. Guten Appetit!",
#   "ingredients": {
#     "57849ac477d68dc4708b4567": {
#       "name": "Rindergeschnetzeltes",
#       "amount": 125.0,
#       "unit": "g",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fb4e",
#         "name": "Rindfleisch"
#       }
#     },
#     "554b1f6efd2cb99c598b4575": {
#       "name": "Jasminreis",
#       "amount": 75.0,
#       "unit": "g",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc1c",
#         "name": "Reis"
#       }
#     },
#     "554b7b9efd2cb9d0608b456f": {
#       "name": "Brokkoli",
#       "amount": 0.5,
#       "unit": "Stück",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fb56",
#         "name": "Brokkoli"
#       }
#     },
#     "554b2abcf8b25eef3e8b4573": {
#       "name": "rote Zwiebel",
#       "amount": 0.5,
#       "unit": "Stück",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fbee",
#         "name": "Zwiebel"
#       }
#     },
#     "554b27e6fd2cb983608b4569": {
#       "name": "Frühlingszwiebel",
#       "amount": 0.5,
#       "unit": "Stück",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc35",
#         "name": "Frühlingszwiebel"
#       }
#     },
#     "554b23dff8b25ef53e8b456f": {
#       "name": "Karotte",
#       "amount": 0.5,
#       "unit": "Stück",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fb62",
#         "name": "Karotte"
#       }
#     },
#     "57ad86a877d68de53f8b4567": {
#       "name": "Gewürzmischung \"Bulgogi\"",
#       "amount": 1.5,
#       "unit": "g",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc32",
#         "name": "Gewürzmischung"
#       }
#     },
#     "554b7d36fd2cb9d8608b4570": {
#       "name": "Sojasoße",
#       "amount": 10.0,
#       "unit": "ml",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc30",
#         "name": "Sojasauce"
#       }
#     },
#     "5582cd024dab71bf498b4567": {
#       "name": "Kartoffelstärke",
#       "amount": 4.0,
#       "unit": "g",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fba0",
#         "name": "Mehl"
#       }
#     },
#     "554b1bf6f8b25eef3e8b4570": {
#       "name": "Öl*",
#       "amount": 0.0,
#       "unit": "Esslöffel",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fbe8",
#         "name": "Öl"
#       }
#     },
#     "554b1c284dab71a9058b456b": {
#       "name": "Salz*",
#       "amount": 0.0,
#       "unit": "nach Geschmack",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc25",
#         "name": "Salz"
#       }
#     },
#     "55b0a135fd2cb9121e8b4567": {
#       "name": "Pfeffer*",
#       "amount": 0.0,
#       "unit": "nach Geschmack",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc05",
#         "name": "Pfeffer (Gewürz)"
#       }
#     },
#     "5568422afd2cb984278b4568": {
#       "name": "Wasser*",
#       "amount": 150.0,
#       "unit": "ml",
#       "family": {
#         "id": "58877cf3ed71a76e9c03fc51",
#         "name": "Wasser"
#       }
#     }
#   },
#   "nutration": {
#     "57b42a48b7e8697d4b30530d": {
#       "amount": 2377,
#       "unit": "kJ",
#       "name": "Energie (kJ)"
#     },
#     "57b42a48b7e8697d4b305304": {
#       "amount": 568,
#       "unit": "kcal",
#       "name": "Energie (kcal)"
#     },
#     "57b42a48b7e8697d4b305307": {
#       "amount": 12,
#       "unit": "g",
#       "name": "Fett"
#     },
#     "57b42a48b7e8697d4b305308": {
#       "amount": 4,
#       "unit": "g",
#       "name": "davon gesättigte Fettsäuren"
#     },
#     "57b42a48b7e8697d4b305305": {
#       "amount": 74,
#       "unit": "g",
#       "name": "Kohlenhydrate"
#     },
#     "57b42a48b7e8697d4b305306": {
#       "amount": 11,
#       "unit": "g",
#       "name": "davon Zucker"
#     },
#     "57b42a48b7e8697d4b30530a": {
#       "amount": 7,
#       "unit": "g",
#       "name": "Ballaststoffe"
#     },
#     "57b42a48b7e8697d4b305309": {
#       "amount": 42,
#       "unit": "g",
#       "name": "Eiweiß"
#     },
#     "57b42a48b7e8697d4b30530c": {
#       "amount": 0,
#       "unit": "mg",
#       "name": "Cholesterol"
#     },
#     "57b42a48b7e8697d4b30530b": {
#       "amount": 4,
#       "unit": "g",
#       "name": "Salz"
#     }
#   },
#   "allergies": {
#     "57962a07b7e8697d4b3052f5": "Weizen",
#     "57962a07b7e8697d4b3052f9": "Soja",
#     "57962a07b7e8697d4b3052f3": "kann Spuren von Allergenen enthalten"
#   },
#   "tags": {
#     "58aeb949c9fd0851d339ede2": "Neuentdeckung",
#     "57d13370b7e8697d4b30531a": "leichter Genuss"
#   },
#   "steps": [
#     "Wasche Gemüse, Kräuter und Fleisch ab und tupfe das Fleisch mit Küchenpapier trocken. Erhitze 350 ml [525 ml|700 ml] Wasser im Wasserkocher. Zum Kochen benötigst Du außerdem 1 große Schüssel, 1 große Pfanne und ein Sieb.\nIn einer großen Schüssel Gewürzmischung mit Speisestärke sowie 2 – 4 EL kaltem Wasser* glatt rühren. Rindergeschnetzeltes darin marinieren.",
#     "Karotte schälen und in dünne Scheiben schneiden. Brokkoli in kleine Röschen aufteilen. Weißen und grünen Teil der Frühlingszwiebel getrennt voneinander in dünne Ringe schneiden. Rote Zwiebel schälen, halbieren und Hälften nochmals halbieren.",
#     "Jasminreis in einem Sieb mit kaltem Wasser abspülen, bis dieses klar hindurchfließt. Kochendes Wasser* in einen großen Topf geben, salzen*, aufkochen lassen, Reis zugeben und mit aufgesetztem Deckel bei niedriger Hitze ca. 10 Min. weiterköcheln lassen.",
#     "Ca. 5 Min. vor Ende der Reis-Garzeit Brokkoliröschen und Karottenscheiben in ein Sieb geben, über den Topf hängen und zugedeckt dämpfen lassen. Nach Ende der Garzeit Sieb mit dem Gemüse beiseitestellen. Topf vom Herd nehmen und Reis mind. 10 Min. abgedeckt ziehen lassen.",
#     "In einer großen Pfanne Öl* erhitzen und mariniertes Rindergeschnetzeltes bei starker Hitze ca. 3 Min. anbraten. Anschließend salzen* und pfeffern* und aus der Pfanne nehmen. Erneut Öl* in der Pfanne erhitzen, weiße Frühlingszwiebelringe, Zwiebelviertel, Brokkoliröschen und Karottenscheiben zugeben und 3 – 5 Min. anbraten. Rindergeschnetzeltes zugeben. Sojasoße mit heißem Wasser* verdünnen und Inhalt der Pfanne damit ablöschen.",
#     "Reis mit einer Gabel auflockern, auf tiefe Teller verteilen, Bulgogi mit Karotten-Brokkoli-Gemüse darauf anrichten, mit den restlichen Frühlingszwiebelringen bestreuen und genießen.\nGuten Appetit!"
#   ]
# }
